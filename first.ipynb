# %% [markdown]
# <a href="https://colab.research.google.com/github/Cheng-Hsun/finlab/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finlab > log.txt

# %%
from finlab import data

close = data.get('price:收盤價')

close[['2330', '2454']].plot()
# Out:
# <Axes: xlabel='date'>
